# %%
import pandas as pd

# %%
complaints = pd.read_table('data/FLAT_CMPL.txt', sep = '\t', header = None, error_bad_lines = False)
# Out:
# /var/folders/w8/wfcl37392dg8532klypndfxxj3jskc/T/ipykernel_95774/3707055367.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   complaints = pd.read_table('data/FLAT_CMPL.txt', sep = '\t', header = None, error_bad_lines = False)
# b'Skipping line 555896: expected 49 fields, saw 70\n'
# /var/folders/w8/wfcl37392dg8532klypndfxxj3jskc/T/ipykernel_95774/3707055367.py:1: DtypeWarning: Columns (15,16,18,28,30,32,33,34,35,38,39,40,41,42,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   complaints = pd.read_table('data/FLAT_CMPL.txt', sep = '\t', header = None, error_bad_lines = False)

# %%
complaints
# Out:
#               0         1                                  2           3   \
# 0              1    958241                 Volvo Car USA, LLC       VOLVO
# 1              2    958130                 Ford Motor Company        FORD
# 2              3    958132                  Kia America, Inc.         KIA
# 3              4    958133             Chrysler (FCA US, LLC)       DODGE
# 4              5    958137             Chrysler (FCA US, LLC)       DODGE
# ...          ...       ...                                ...         ...
# 1873259  1874184  11508250  Volkswagen Group of America, Inc.  VOLKSWAGEN
# 1873260  1874185  11508251                General Motors, LLC   CHEVROLET
# 1873261  1874186  11508251                General Motors, LLC   CHEVROLET
# 1873262  1874187  11508251                General Motors, LLC   CHEVROLET
# 1873263  1874188  11508252  Volkswagen Group of America, Inc.  VOLKSWAGEN
#
#                   4       5  6           7  8   9   ...   39   40   41   42  \
# ...
