# %%
import pandas as pd

# %%
#read txt file using pandas, fixed width

# %%
complaints = pd.read_fwf('data/FLAT_CMPL.txt', header = None)

# %%
complaints
# Out:
#                                                          0       1    2    3  \
# 0        1\t958241\tVolvo Car USA, LLC\tVOLVO\t760\t198...     NaN  NaN  NaN
# 1        2\t958130\tFord Motor Company\tFORD\tTHUNDERBI...     NaN  NaN  NaN
# 2        3\t958132\tKia America, Inc.\tKIA\tSEPHIA\t199...     NaN  NaN  NaN
# 3        4\t958133\tChrysler (FCA US, LLC)\tDODGE\t600\...     NaN  NaN  NaN
# 4        5\t958137\tChrysler (FCA US, LLC)\tDODGE\tCARA...     NaN  NaN  NaN
# ...                                                    ...     ...  ...  ...
# 1874183  1874184\t11508250\tVolkswagen Group of America...     NaN    0  NaN
# 1874184  1874185\t11508251\tGeneral Motors, LLC\tCHEVRO...     NaN  NaN  NaN
# 1874185  1874186\t11508251\tGeneral Motors, LLC\tCHEVRO...     NaN  NaN  NaN
# 1874186  1874187\t11508251\tGeneral Motors, LLC\tCHEVRO...     NaN  NaN  NaN
# 1874187  1874188\t11508252\tVolkswagen Group of America...  ssembl  NaN    r
#
#            4    5    6     7
# ...

# %%
#complaints 0 is /t delimited

# %%
df = complaints[0].str.split("\t",expand=True)

# %%
df
# Out:
#               0         1                                  2           3   \
# 0              1    958241                 Volvo Car USA, LLC       VOLVO
# 1              2    958130                 Ford Motor Company        FORD
# 2              3    958132                  Kia America, Inc.         KIA
# 3              4    958133             Chrysler (FCA US, LLC)       DODGE
# 4              5    958137             Chrysler (FCA US, LLC)       DODGE
# ...          ...       ...                                ...         ...
# 1874183  1874184  11508250  Volkswagen Group of America, Inc.  VOLKSWAGEN
# 1874184  1874185  11508251                General Motors, LLC   CHEVROLET
# 1874185  1874186  11508251                General Motors, LLC   CHEVROLET
# 1874186  1874187  11508251                General Motors, LLC   CHEVROLET
# 1874187  1874188  11508252  Volkswagen Group of America, Inc.  VOLKSWAGEN
#
#                   4     5  6         7  8  9   ...    39    40    41    42  \
# ...

# %%
df[3].str.contains("TESLA").value_counts()
# Out:
# False    1862797
# True       11391
# Name: 3, dtype: int64

# %%
inv1 = pd.read_fwf("data/flat_inv.txt", header = None)

# %%
inv1_clean = inv1[0].str.split("\t", expand = True)

# %%
##inv1_clean[1].str.contains["TESLA"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/w8/wfcl37392dg8532klypndfxxj3jskc/T/ipykernel_3214/1385215940.py in <module>
# ----> 1 inv1_clean[1].str.contains["TESLA"]
#
# TypeError: 'method' object is not subscriptable

# %%
inv1_clean[1]=="TESLA"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 163307    False
# 163308    False
# 163309    False
# 163310    False
# 163311    False
# Name: 1, Length: 163312, dtype: bool

# %%
tesla = inv1_clean.loc[inv1_clean[1] == "TESLA"]

# %%
tesla.head(20)
# Out:
#             0      1        2     3   \
# 16004  PE16007  TESLA  MODEL S  2014
# 16005  PE16007  TESLA  MODEL S  2014
# 16006  PE16007  TESLA  MODEL S  2014
# 16007  PE16007  TESLA  MODEL S  2015
# 16008  PE16007  TESLA  MODEL X  2016
# 19077  DP19005  TESLA  MODEL S  2012
# 19078  DP19005  TESLA  MODEL S  2014
# 19079  DP19005  TESLA  MODEL S  2015
# 19080  DP19005  TESLA  MODEL S  2016
# 19081  DP19005  TESLA  MODEL S  2017
# 19082  DP19005  TESLA  MODEL S  2017
# 19083  DP19005  TESLA  MODEL S  2019
# 19084  DP19005  TESLA  MODEL X  2019
# 19139  DP20001  TESLA  MODEL 3  2017
# 19140  DP20001  TESLA  MODEL 3  2017
# 19141  DP20001  TESLA  MODEL 3  2017
# 19142  DP20001  TESLA  MODEL 3  2017
# 19143  DP20001  TESLA  MODEL 3  2017
# 19144  DP20001  TESLA  MODEL 3  2017
# 19145  DP20001  TESLA  MODEL 3  2017
#
#                                                       4            5   \
# 16004  FORWARD COLLISION AVOIDANCE: ADAPTIVE CRUISE C...  Tesla, Inc.
# ...

# %%
len(tesla)
# Out:
# 1110

# %%
tesla_clean = tesla.drop_duplicates(subset = 0)

# %%
len(tesla_clean)
# Out:
# 13

# %%
tesla_clean
# Out:
#             0      1        2     3   \
# 16004  PE16007  TESLA  MODEL S  2014
# 19077  DP19005  TESLA  MODEL S  2012
# 19139  DP20001  TESLA  MODEL 3  2017
# 19282  PE20010  TESLA  MODEL S  2015
# 19329  EA20003  TESLA  MODEL S  2012
# 19335  PE20020  TESLA  MODEL X  2017
# 19818  EA21002  TESLA  MODEL X  2018
# 19910  PE21020  TESLA  MODEL 3  2021
# 19929  PE21023  TESLA  MODEL 3  2020
# 19930  PE22002  TESLA  MODEL 3  2021
# 19964  EA22002  TESLA  MODEL S  2020
# 20098  DP22005  TESLA  MODEL 3  2020
# 45837  PE13037  TESLA  MODEL S  2013
#
#                                                       4            5   \
# 16004  FORWARD COLLISION AVOIDANCE: ADAPTIVE CRUISE C...  Tesla, Inc.
# 19077  ELECTRICAL SYSTEM:PROPULSION SYSTEM:TRACTION B...  Tesla, Inc.
# 19139                  ELECTRICAL SYSTEM:IGNITION:MODULE  Tesla, Inc.
# 19282       BACK OVER PREVENTION: SENSING SYSTEM: CAMERA  Tesla, Inc.
# 19329       BACK OVER PREVENTION: SENSING SYSTEM: CAMERA  Tesla, Inc.
# ...

# %%
inv2 = pd.read_fwf("data/flat_inv 2.txt", header = None)

# %%
inv2_clean = inv2[0].str.split("\t", expand = True)

# %%
tesla2 = inv2_clean.loc[inv2_clean[1] == "TESLA"]

# %%
tesla2.head(20)
# Out:
#             0      1        2     3   \
# 16004  PE16007  TESLA  MODEL S  2014
# 16005  PE16007  TESLA  MODEL S  2014
# 16006  PE16007  TESLA  MODEL S  2014
# 16007  PE16007  TESLA  MODEL S  2015
# 16008  PE16007  TESLA  MODEL X  2016
# 19077  DP19005  TESLA  MODEL S  2012
# 19078  DP19005  TESLA  MODEL S  2014
# 19079  DP19005  TESLA  MODEL S  2015
# 19080  DP19005  TESLA  MODEL S  2016
# 19081  DP19005  TESLA  MODEL S  2017
# 19082  DP19005  TESLA  MODEL S  2017
# 19083  DP19005  TESLA  MODEL S  2019
# 19084  DP19005  TESLA  MODEL X  2019
# 19139  DP20001  TESLA  MODEL 3  2017
# 19140  DP20001  TESLA  MODEL 3  2017
# 19141  DP20001  TESLA  MODEL 3  2017
# 19142  DP20001  TESLA  MODEL 3  2017
# 19143  DP20001  TESLA  MODEL 3  2017
# 19144  DP20001  TESLA  MODEL 3  2017
# 19145  DP20001  TESLA  MODEL 3  2017
#
#                                                       4            5   \
# 16004  FORWARD COLLISION AVOIDANCE: ADAPTIVE CRUISE C...  Tesla, Inc.
# ...

# %%
len(tesla2)
# Out:
# 1110

# %%
tesla_clean.to_csv("tesla_clean.csv", encoding="utf-8")
